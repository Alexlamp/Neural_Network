# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
y_train=y_train.to_numpy()

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Train on 576 samples
# Epoch 1/100
# 576/576 [==============================] - 1s 1ms/sample - loss: 0.7090 - accuracy: 0.6250
# Epoch 2/100
# 576/576 [==============================] - 0s 78us/sample - loss: 0.6807 - accuracy: 0.6528
# Epoch 3/100
# 576/576 [==============================] - 0s 156us/sample - loss: 0.6547 - accuracy: 0.6684
# Epoch 4/100
# 576/576 [==============================] - 0s 78us/sample - loss: 0.6333 - accuracy: 0.6771
# Epoch 5/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.6132 - accuracy: 0.7031
# Epoch 6/100
# 576/576 [==============================] - 0s 79us/sample - loss: 0.5951 - accuracy: 0.7135
# Epoch 7/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.5792 - accuracy: 0.7170
# Epoch 8/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.5649 - accuracy: 0.7240
# Epoch 9/100
# 576/576 [==============================] - 0s 79us/sample - loss: 0.5519 - accuracy: 0.7326
# Epoch 10/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.5414 - accuracy: 0.7361
# Epoch 11/100
# 576/576 [==============================] - 0s 72us/sample - loss: 0.5315 - accuracy: 0.7413
# Epoch 12/100
# 576/576 [==============================] - 0s 72us/sample - loss: 0.5230 - accuracy: 0.7483
# Epoch 13/100
# 576/576 [==============================] - 0s 80us/sample - loss: 0.5163 - accuracy: 0.7569
# Epoch 14/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.5096 - accuracy: 0.7604
# Epoch 15/100
# 576/576 [==============================] - 0s 78us/sample - loss: 0.5039 - accuracy: 0.7622
# Epoch 16/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4989 - accuracy: 0.7656
# Epoch 17/100
# 576/576 [==============================] - 0s 79us/sample - loss: 0.4945 - accuracy: 0.7587
# Epoch 18/100
# 576/576 [==============================] - 0s 70us/sample - loss: 0.4904 - accuracy: 0.7569
# Epoch 19/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.4868 - accuracy: 0.7639
# Epoch 20/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4838 - accuracy: 0.7639
# Epoch 21/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4814 - accuracy: 0.7656
# Epoch 22/100
# 576/576 [==============================] - 0s 73us/sample - loss: 0.4783 - accuracy: 0.7674
# Epoch 23/100
# 576/576 [==============================] - 0s 70us/sample - loss: 0.4760 - accuracy: 0.7674
# Epoch 24/100
# 576/576 [==============================] - 0s 69us/sample - loss: 0.4736 - accuracy: 0.7639
# Epoch 25/100
# 576/576 [==============================] - 0s 81us/sample - loss: 0.4719 - accuracy: 0.7656
# Epoch 26/100
# 576/576 [==============================] - 0s 96us/sample - loss: 0.4698 - accuracy: 0.7691
# Epoch 27/100
# 576/576 [==============================] - 0s 70us/sample - loss: 0.4684 - accuracy: 0.7778
# Epoch 28/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4668 - accuracy: 0.7795
# Epoch 29/100
# 576/576 [==============================] - 0s 78us/sample - loss: 0.4653 - accuracy: 0.7847
# Epoch 30/100
# 576/576 [==============================] - 0s 81us/sample - loss: 0.4643 - accuracy: 0.7865
# Epoch 31/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.4629 - accuracy: 0.7899
# Epoch 32/100
# 576/576 [==============================] - 0s 69us/sample - loss: 0.4618 - accuracy: 0.7899
# Epoch 33/100
# 576/576 [==============================] - 0s 78us/sample - loss: 0.4606 - accuracy: 0.7899
# Epoch 34/100
# 576/576 [==============================] - 0s 69us/sample - loss: 0.4596 - accuracy: 0.7882
# Epoch 35/100
# 576/576 [==============================] - 0s 101us/sample - loss: 0.4585 - accuracy: 0.7899
# Epoch 36/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4577 - accuracy: 0.7917
# Epoch 37/100
# 576/576 [==============================] - 0s 76us/sample - loss: 0.4566 - accuracy: 0.7899
# Epoch 38/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.4559 - accuracy: 0.7865
# Epoch 39/100
# 576/576 [==============================] - 0s 74us/sample - loss: 0.4549 - accuracy: 0.7865
# Epoch 40/100
# 576/576 [==============================] - 0s 77us/sample - loss: 0.4540 - accuracy: 0.7865
# Epoch 41/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4534 - accuracy: 0.7882
# Epoch 42/100
# 576/576 [==============================] - 0s 72us/sample - loss: 0.4525 - accuracy: 0.7899
# Epoch 43/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.4514 - accuracy: 0.7917
# Epoch 44/100
# 576/576 [==============================] - 0s 76us/sample - loss: 0.4506 - accuracy: 0.7899
# Epoch 45/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4500 - accuracy: 0.7899
# Epoch 46/100
# 576/576 [==============================] - 0s 81us/sample - loss: 0.4490 - accuracy: 0.7899
# Epoch 47/100
# 576/576 [==============================] - 0s 62us/sample - loss: 0.4482 - accuracy: 0.7882
# Epoch 48/100
# 576/576 [==============================] - 0s 139us/sample - loss: 0.4474 - accuracy: 0.7882
# Epoch 49/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4466 - accuracy: 0.7882
# Epoch 50/100
# 576/576 [==============================] - 0s 86us/sample - loss: 0.4457 - accuracy: 0.7917
# Epoch 51/100
# 576/576 [==============================] - 0s 87us/sample - loss: 0.4451 - accuracy: 0.7951
# Epoch 52/100
# 576/576 [==============================] - 0s 89us/sample - loss: 0.4443 - accuracy: 0.7917
# Epoch 53/100
# 576/576 [==============================] - 0s 113us/sample - loss: 0.4435 - accuracy: 0.7934
# Epoch 54/100
# 576/576 [==============================] - 0s 148us/sample - loss: 0.4429 - accuracy: 0.7917
# Epoch 55/100
# 576/576 [==============================] - 0s 88us/sample - loss: 0.4419 - accuracy: 0.7934
# Epoch 56/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4416 - accuracy: 0.7951
# Epoch 57/100
# 576/576 [==============================] - 0s 73us/sample - loss: 0.4407 - accuracy: 0.7951
# Epoch 58/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4403 - accuracy: 0.7951
# Epoch 59/100
# 576/576 [==============================] - 0s 75us/sample - loss: 0.4394 - accuracy: 0.7969
# Epoch 60/100
# 576/576 [==============================] - 0s 63us/sample - loss: 0.4388 - accuracy: 0.7969
# Epoch 61/100
# 576/576 [==============================] - 0s 64us/sample - loss: 0.4383 - accuracy: 0.7986
# Epoch 62/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4376 - accuracy: 0.7969
# Epoch 63/100
# 576/576 [==============================] - 0s 61us/sample - loss: 0.4374 - accuracy: 0.8003
# Epoch 64/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4365 - accuracy: 0.7986
# Epoch 65/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.4357 - accuracy: 0.8021
# Epoch 66/100
# 576/576 [==============================] - 0s 77us/sample - loss: 0.4355 - accuracy: 0.8021
# Epoch 67/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.4347 - accuracy: 0.8021
# Epoch 68/100
# 576/576 [==============================] - 0s 70us/sample - loss: 0.4343 - accuracy: 0.8003
# Epoch 69/100
# 576/576 [==============================] - 0s 133us/sample - loss: 0.4335 - accuracy: 0.8021
# Epoch 70/100
# 576/576 [==============================] - 0s 130us/sample - loss: 0.4329 - accuracy: 0.8038
# Epoch 71/100
# 576/576 [==============================] - 0s 101us/sample - loss: 0.4324 - accuracy: 0.8038
# Epoch 72/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.4321 - accuracy: 0.8090
# Epoch 73/100
# 576/576 [==============================] - 0s 70us/sample - loss: 0.4313 - accuracy: 0.8056
# Epoch 74/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.4307 - accuracy: 0.8056
# Epoch 75/100
# 576/576 [==============================] - 0s 85us/sample - loss: 0.4301 - accuracy: 0.8038
# Epoch 76/100
# 576/576 [==============================] - 0s 91us/sample - loss: 0.4297 - accuracy: 0.8073
# Epoch 77/100
# 576/576 [==============================] - 0s 84us/sample - loss: 0.4291 - accuracy: 0.8056
# Epoch 78/100
# 576/576 [==============================] - 0s 78us/sample - loss: 0.4287 - accuracy: 0.8056
# Epoch 79/100
# 576/576 [==============================] - 0s 83us/sample - loss: 0.4286 - accuracy: 0.8073
# Epoch 80/100
# 576/576 [==============================] - 0s 78us/sample - loss: 0.4284 - accuracy: 0.8021
# Epoch 81/100
# 576/576 [==============================] - 0s 72us/sample - loss: 0.4276 - accuracy: 0.8073
# Epoch 82/100
# 576/576 [==============================] - 0s 73us/sample - loss: 0.4268 - accuracy: 0.8056
# Epoch 83/100
# 576/576 [==============================] - 0s 66us/sample - loss: 0.4266 - accuracy: 0.8038
# Epoch 84/100
# 576/576 [==============================] - 0s 72us/sample - loss: 0.4260 - accuracy: 0.8038
# Epoch 85/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4256 - accuracy: 0.8073
# Epoch 86/100
# 576/576 [==============================] - 0s 78us/sample - loss: 0.4251 - accuracy: 0.8073
# Epoch 87/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.4249 - accuracy: 0.8073
# Epoch 88/100
# 576/576 [==============================] - 0s 72us/sample - loss: 0.4245 - accuracy: 0.8073
# Epoch 89/100
# 576/576 [==============================] - 0s 81us/sample - loss: 0.4243 - accuracy: 0.8073
# Epoch 90/100
# 576/576 [==============================] - 0s 80us/sample - loss: 0.4236 - accuracy: 0.8073
# Epoch 91/100
# 576/576 [==============================] - 0s 120us/sample - loss: 0.4234 - accuracy: 0.8090
# Epoch 92/100
# 576/576 [==============================] - 0s 66us/sample - loss: 0.4230 - accuracy: 0.8073
# Epoch 93/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4226 - accuracy: 0.8090
# Epoch 94/100
# 576/576 [==============================] - 0s 65us/sample - loss: 0.4222 - accuracy: 0.8090
# Epoch 95/100
# 576/576 [==============================] - 0s 69us/sample - loss: 0.4221 - accuracy: 0.8073
# Epoch 96/100
# 576/576 [==============================] - 0s 71us/sample - loss: 0.4217 - accuracy: 0.8090
# Epoch 97/100
# 576/576 [==============================] - 0s 59us/sample - loss: 0.4217 - accuracy: 0.8108
# Epoch 98/100
# 576/576 [==============================] - 0s 67us/sample - loss: 0.4212 - accuracy: 0.8073
# Epoch 99/100
# 576/576 [==============================] - 0s 79us/sample - loss: 0.4208 - accuracy: 0.8125
# Epoch 100/100
# 576/576 [==============================] - 0s 68us/sample - loss: 0.4205 - accuracy: 0.8108
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-eb7d1cfda544> in <module>
#      11
#      12 # Evaluate the model using the test data
# ---> 13 model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
#      14 print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     831         max_queue_size=max_queue_size,
#     832         workers=workers,
# --> 833         use_multiprocessing=use_multiprocessing)
#     834
#     835   def predict(self,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in evaluate(self, model, x, y, batch_size, verbose, sample_weight, steps, callbacks, **kwargs)
#     454     return self._model_iteration(
#     455         model, ModeKeys.TEST, x=x, y=y, batch_size=batch_size, verbose=verbose,
# --> 456         sample_weight=sample_weight, steps=steps, callbacks=callbacks, **kwargs)
#     457
#     458   def predict(self, model, x, batch_size=None, verbose=0, steps=None,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in _model_iteration(self, model, mode, x, y, batch_size, verbose, sample_weight, steps, callbacks, **kwargs)
#     394           sample_weights=sample_weight,
#     395           steps=steps,
# --> 396           distribution_strategy=strategy)
#     397       total_samples = _get_total_number_of_samples(adapter)
#     398       use_sample = total_samples is not None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in _process_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, shuffle, steps, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     583                     use_multiprocessing=False):
#     584   """Process the inputs for fit/eval/predict()."""
# --> 585   adapter_cls = data_adapter.select_data_adapter(x, y)
#     586   if adapter_cls in _ADAPTER_FOR_STANDARDIZE_USER_DATA:
#     587     x, y, sample_weights = model._standardize_user_data(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/data_adapter.py in select_data_adapter(x, y)
#     651         "Failed to find data adapter that can handle "
#     652         "input: {}, {}".format(
# --> 653             _type_name(x), _type_name(y)))
#     654   elif len(adapter_cls) > 1:
#     655     raise RuntimeError(
#
# ValueError: Failed to find data adapter that can handle input: <class 'numpy.ndarray'>, <class 'pandas.core.series.Series'>
